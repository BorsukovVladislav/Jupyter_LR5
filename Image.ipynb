# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import requests
from io import BytesIO
plt.figure(figsize=(10, 10))
response_cat1 = requests.get('https://kartinkin.net/uploads/posts/2022-03/1647554296_8-kartinkin-net-p-multyashnie-koshki-kartinki-8.jpg')
img_cat1 = Image.open(BytesIO(response_cat1.content))
plt.imshow(img_cat1)
